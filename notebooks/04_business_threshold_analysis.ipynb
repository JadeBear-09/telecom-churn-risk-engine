# %% [markdown]
# # 04 Business Threshold Analysis
#
# Inspect threshold tuning tradeoffs between false negative cost and false positive cost.

# %%
import json
import pandas as pd
metrics = json.load(open('../models/metrics.json'))
thresholds = pd.DataFrame(metrics['threshold_tuning'])
thresholds.sort_values('total_cost').head(10)
