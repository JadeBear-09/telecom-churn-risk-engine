# %% [markdown]
# # 03 Model Training
#
# Train candidate models and inspect saved metrics.

# %%
from src.train import train_pipeline
metrics = train_pipeline()
{k: metrics[k] for k in ['model_name', 'roc_auc', 'precision', 'recall', 'f1', 'selected_threshold']}
