# %% [markdown]
# # 02 Feature Engineering
#
# Review engineered churn drivers and synthetic telecom operations features.

# %%
from src.train import prepare_training_data
from src.feature_engineering import ENGINEERED_FEATURES
df = prepare_training_data()
df[ENGINEERED_FEATURES + ['churn']].describe().T
