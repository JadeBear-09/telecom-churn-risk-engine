# %% [markdown]
# # 01 EDA
#
# Explore churn rate, contract mix, charges, tenure, and operational signals.

# %%
from src.train import prepare_training_data
df = prepare_training_data()
df.head()

# %%
df['churn'].value_counts(normalize=True).rename('churn_rate')
